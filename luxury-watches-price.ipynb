# %% [markdown]
# # Luxury Watch
#
# **Column Details**
# * Brand: The brand of the watch.
# * Model: The model name or number of the watch.
# * Case Material: The material used to make the watch case (e.g., stainless steel, titanium, gold).
# * Strap Material: The material used to make the watch strap or bracelet (e.g., leather, rubber, metal).
# * Movement Type: The type of movement used in the watch (e.g., automatic, manual, quartz).
# * Water Resistance: The level of water resistance for the watch (e.g., 30 meters, 100 meters, 600 meters).
# * Case Diameter (mm): The diameter of the watch case in millimeters.
# * Case Thickness (mm): The thickness of the watch case in millimeters.
# * Band Width (mm): The width of the watch strap or bracelet in millimeters.
# * Dial Color: The color of the watch dial (e.g., black, blue, silver).
# * Crystal Material: The material used for the watch crystal (e.g., sapphire, mineral, hardlex).
# * Complications: Any additional functions or features beyond timekeeping (e.g., date display, chronograph, GMT).
# * Power Reserve: The amount of time the watch can run without winding or wearing (e.g., 48 hours, 72 hours).
# * Price (USD): The retail price of the watch in US dollars.

# %%
path = "https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/Luxurywatch.csv"

# %%
import pandas as pd
df=pd.read_csv(path)
df
# Out:
#                    Brand              Model    Case Material   Strap Material  \
# 0                  Rolex         Submariner  Stainless Steel  Stainless Steel
# 1                  Omega          Seamaster         Titanium           Rubber
# 2              Tag Heuer            Carrera  Stainless Steel          Leather
# 3              Breitling          Navitimer  Stainless Steel  Stainless Steel
# 4                Cartier          Tank Solo  Stainless Steel          Leather
# ..                   ...                ...              ...              ...
# 502              Breguet          Classique    18k Rose Gold          Leather
# 503            Blancpain      Fifty Fathoms  Stainless Steel           Fabric
# 504             Longines  Master Collection  Stainless Steel          Leather
# 505  Vacheron Constantin           Overseas  Stainless Steel  Stainless Steel
# 506  Frederique Constant           Classics  Stainless Steel          Leather
#
#     Movement Type Water Resistance  Case Diameter (mm)  Case Thickness (mm)  \
# 0       Automatic       300 meters                40.0                13.00
# 1       Automatic       600 meters                43.5                14.47
# 2       Automatic       100 meters                41.0                13.00
# 3       Automatic        30 meters                43.0                14.25
# 4          Quartz        30 meters                31.0                 6.05
# ..            ...              ...                 ...                  ...
# 502     Automatic        30 meters                38.5                 8.25
# 503     Automatic       300 meters                45.0                15.50
# 504     Automatic        30 meters                38.5                 9.70
# 505     Automatic       150 meters                41.5                11.00
# 506     Automatic        50 meters                40.0                10.60
#
#      Band Width (mm) Dial Color Crystal Material Complications Power Reserve  \
# 0               20.0      Black         Sapphire          Date      48 hours
# 1               21.0       Blue         Sapphire          Date      60 hours
# 2               20.0      White         Sapphire   Chronograph      42 hours
# 3               22.0      Black         Sapphire   Chronograph      70 hours
# 4               20.0     Silver         Sapphire           NaN           NaN
# ..               ...        ...              ...           ...           ...
# 502             20.0      White         Sapphire          Date      38 hours
# 503             23.0      Black         Sapphire          Date     120 hours
# 504             20.0       Blue         Sapphire          Date      64 hours
# 505             22.0       Blue         Sapphire          Date      40 hours
# 506             20.0     Silver         Sapphire          Date      38 hours
#
#     Price (USD)
# 0         9,500
# 1         5,800
# 2         4,200
# 3         7,900
# 4         2,800
# ..          ...
# 502      21,500
# 503      13,500
# 504       1,800
# 505      19,000
# 506       1,200
#
# [507 rows x 14 columns]

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.drop(df.loc[df["Power Reserve"] == "270 days"].index, inplace=True)
df.drop(df.loc[df["Power Reserve"] == "210 days"].index, inplace=True)
df.drop(df.loc[df["Power Reserve"] == "4,200"].index, inplace=True)

# %%
df["Power Reserve"].value_counts()
# Out:
# Power Reserve
# 60 hours     82
# 42 hours     55
# 70 hours     50
# 50 hours     40
# 72 hours     38
# 120 hours    30
# 45 hours     29
# 48 hours     27
# 38 hours     27
# 40 hours     22
# 54 hours     15
# 46 hours     13
# 65 hours     11
# 44 hours     10
# 55 hours     10
# 56 hours      8
# 64 hours      6
# 68 hours      6
# 43 hours      5
# 80 hours      4
# 41 hours      1
# 168 hours     1
# Name: count, dtype: int64

# %%
df["Power Reserve"]=df['Power Reserve'].str.replace(' hours', '')
df["Power Reserve"]=df['Power Reserve'].str.replace(' days', '')
df["Power Reserve"]=df["Power Reserve"].astype(float)

# %%
df["Water Resistance"]=df['Water Resistance'].str.replace(' meters', '')
df["Water Resistance"]=df["Water Resistance"].astype(int)

# %%
df["Water Resistance"].value_counts()
# Out:
# Water Resistance
# 100     129
# 50      112
# 30      104
# 300      63
# 200      27
# 120      26
# 150      20
# 60       13
# 1000      4
# 500       3
# 600       2
# 2000      1
# Name: count, dtype: int64

# %%
df["Water Resistance"].isnull().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                      count       mean       std   min   25%   50%   75%   max
# Case Diameter (mm)   507.0  41.046154  2.535339  27.5  40.0  41.0  42.0  46.5
# Case Thickness (mm)  507.0  11.588343  2.491481   5.0   9.8  12.0  13.3  17.5
# Band Width (mm)      507.0  21.105523  1.658375  15.0  20.0  20.0  22.0  28.0

# %%
df.isnull().sum()
# Out:
# Brand                  0
# Model                  0
# Case Material          0
# Strap Material         0
# Movement Type          0
# Water Resistance       0
# Case Diameter (mm)     0
# Case Thickness (mm)    0
# Band Width (mm)        0
# Dial Color             0
# Crystal Material       0
# Complications          0
# Power Reserve          0
# Price (USD)            0
# dtype: int64

# %%
df["Complications"]=df['Complications'].fillna(df['Complications'].mode()[0])

# %%
df
# Out:
#                    Brand              Model    Case Material   Strap Material  \
# 0                  Rolex         Submariner  Stainless Steel  Stainless Steel
# 1                  Omega          Seamaster         Titanium           Rubber
# 2              Tag Heuer            Carrera  Stainless Steel          Leather
# 3              Breitling          Navitimer  Stainless Steel  Stainless Steel
# 5       Jaeger-LeCoultre            Reverso  Stainless Steel          Leather
# ..                   ...                ...              ...              ...
# 502              Breguet          Classique    18k Rose Gold          Leather
# 503            Blancpain      Fifty Fathoms  Stainless Steel           Fabric
# 504             Longines  Master Collection  Stainless Steel          Leather
# 505  Vacheron Constantin           Overseas  Stainless Steel  Stainless Steel
# 506  Frederique Constant           Classics  Stainless Steel          Leather
#
#     Movement Type  Water Resistance  Case Diameter (mm)  Case Thickness (mm)  \
# 0       Automatic               300                40.0                13.00
# 1       Automatic               600                43.5                14.47
# 2       Automatic               100                41.0                13.00
# 3       Automatic                30                43.0                14.25
# 5          Manual                30                42.9                 9.20
# ..            ...               ...                 ...                  ...
# 502     Automatic                30                38.5                 8.25
# 503     Automatic               300                45.0                15.50
# 504     Automatic                30                38.5                 9.70
# 505     Automatic               150                41.5                11.00
# 506     Automatic                50                40.0                10.60
#
#      Band Width (mm) Dial Color Crystal Material Complications  Power Reserve  \
# 0               20.0      Black         Sapphire          Date           48.0
# 1               21.0       Blue         Sapphire          Date           60.0
# 2               20.0      White         Sapphire   Chronograph           42.0
# 3               22.0      Black         Sapphire   Chronograph           70.0
# 5               20.0      Black         Sapphire          Date           45.0
# ..               ...        ...              ...           ...            ...
# 502             20.0      White         Sapphire          Date           38.0
# 503             23.0      Black         Sapphire          Date          120.0
# 504             20.0       Blue         Sapphire          Date           64.0
# 505             22.0       Blue         Sapphire          Date           40.0
# 506             20.0     Silver         Sapphire          Date           38.0
#
#      Price (USD)
# 0           9500
# 1           5800
# 2           4200
# 3           7900
# 5           5500
# ..           ...
# 502        21500
# 503        13500
# 504         1800
# 505        19000
# 506         1200
#
# [490 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 490 entries, 0 to 506
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                490 non-null    object
#  1   Model                490 non-null    object
#  2   Case Material        490 non-null    object
#  3   Strap Material       490 non-null    object
#  4   Movement Type        490 non-null    object
#  5   Water Resistance     490 non-null    int32
#  6   Case Diameter (mm)   490 non-null    float64
#  7   Case Thickness (mm)  490 non-null    float64
#  8   Band Width (mm)      490 non-null    float64
#  9   Dial Color           490 non-null    object
#  10  Crystal Material     490 non-null    object
#  11  Complications        490 non-null    object
#  12  Power Reserve        490 non-null    float64
#  13  Price (USD)          490 non-null    int32
# dtypes: float64(4), int32(2), object(8)
# memory usage: 53.6+ KB

# %%
df["Price (USD)"]=df['Price (USD)'].str.replace(',', '')
df["Price (USD)"]=df["Price (USD)"].astype(int)

# %%
df["Price (USD)"].value_counts()
# Out:
# Price (USD)
# 7,500     26
# 6,500     22
# 9,500     16
# 4,500     12
# 5,500     11
#           ..
# 23,100     1
# 20,500     1
# 13,900     1
# 9,950      1
# 35,000     1
# Name: count, Length: 182, dtype: int64

# %%
df=df.dropna()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df)

# %%
sns.pairplot(df,hue="Price (USD)")

# %%
sns.pairplot(df,hue="Water Resistance")

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                      Water Resistance  Case Diameter (mm)  \
# Water Resistance             1.000000            0.359588
# Case Diameter (mm)           0.359588            1.000000
# Case Thickness (mm)          0.382137            0.606269
# Band Width (mm)              0.214095            0.604300
# Power Reserve                0.192545            0.375626
# Price (USD)                 -0.131888           -0.133280
#
#                      Case Thickness (mm)  Band Width (mm)  Power Reserve  \
# Water Resistance                0.382137         0.214095       0.192545
# Case Diameter (mm)              0.606269         0.604300       0.375626
# Case Thickness (mm)             1.000000         0.403927       0.383402
# Band Width (mm)                 0.403927         1.000000       0.323303
# Power Reserve                   0.383402         0.323303       1.000000
# Price (USD)                    -0.449457        -0.111695      -0.003067
#
#                      Price (USD)
# Water Resistance       -0.131888
# Case Diameter (mm)     -0.133280
# Case Thickness (mm)    -0.449457
# Band Width (mm)        -0.111695
# Power Reserve          -0.003067
# Price (USD)             1.000000

# %%
plt.figure(figsize=(19,8))
sns.scatterplot(x="Case Thickness (mm)", y="Price (USD)", data=df);

# %%
plt.figure(figsize=(19,8))
sns.scatterplot(x="Case Thickness (mm)", y="Case Diameter (mm)", data=df);

# %%
plt.figure(figsize=(19,8))
sns.scatterplot(x="Band Width (mm)", y="Case Diameter (mm)", data=df);
